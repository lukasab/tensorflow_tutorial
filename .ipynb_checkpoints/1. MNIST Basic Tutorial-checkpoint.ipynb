# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train/255.0, x_test/255.0

# %% [markdown]
# As imagens são arrays com o valor dos pixels entre 0 e 255. Dividimos os valores para deixar os valores entre 0 e 1.

# %%
models = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])

models.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

models.fit(x_train, y_train, epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.2942 - accuracy: 0.9131
# Epoch 2/5
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.1427 - accuracy: 0.9573
# Epoch 3/5
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.1060 - accuracy: 0.9669
# Epoch 4/5
# 60000/60000 [==============================] - 3s 48us/sample - loss: 0.0859 - accuracy: 0.9739
# Epoch 5/5
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.0736 - accuracy: 0.9766

# %%
models.evaluate(x_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.07445073775653728, 0.9768]
